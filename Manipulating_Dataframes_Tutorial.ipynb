# %% [markdown]
# # Manipulating Dataframes

# %% [markdown]
# In the previous tutorial we covered what a dataframe is, and how to create and access it. Now we will look at how to manipulate dataframes and when to use a dataframe as the chosen data structure.
#
# Let's start by importing the pandas library and the football_players.csv we used in the previous tutorial.

# %%
import pandas as pd

# %%
# Load data - pass 'Name' as our index column
load_df = pd.read_csv('football_players-a-26.csv', index_col='Name')

# Create dataframe called df
df = pd.DataFrame(load_df)

# Use the head() function to look at the first 5 rows
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing         ...          \
# Name                                                              ...
# Cristiano Ronaldo  63           93        95       85             ...
# L. Messi           95           95        96       77             ...
# Neymar             82           95        92       75             ...
# L. Suárez          60           91        83       77             ...
# M. Neuer           35           48        70       15             ...
#
#                   Short passing Shot power Sliding tackle Sprint speed  \
# Name
# Cristiano Ronaldo        83         94             23           91
# L. Messi                 88         85             26           87
# Neymar                   81         80             33           90
# L. Suárez                83         87             38           77
# M. Neuer                 55         25             11           61
#
#                   Stamina Standing tackle Strength  Vision Volleys  \
# Name
# Cristiano Ronaldo  92              31       80      85      88
# L. Messi           73              28       59      90      85
# Neymar             78              24       53      80      83
# L. Suárez          89              45       80      84      88
# M. Neuer           44              10       83      70      11
#
#                   Preferred Positions
# Name
# Cristiano Ronaldo              ST LW
# L. Messi                          RW
# Neymar                            LW
# L. Suárez                         ST
# M. Neuer                          GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Sorting

# %% [markdown]
# Usually one of the first things that is done when working with a large dataset is to sort the values using some criteria. This can be done by using the `sort_values()` function. We need to pass the column to sort by. Let's look at some examples:

# %%
# Sort by age from youngest to oldest (select first 5 entries)
df.sort_values(by='Age').head()
# Out:
#               Age  Nationality  Overall Acceleration Aggression Agility  \
# Name
# J. Romero      16    Argentina       58       75         36      70
# J. Hove        16       Norway       51       57         57      58
# Javi Vázquez   16        Spain       58       61         53      48
# K. Pierie      16  Netherlands       65       72         64      66
# L. Pintor      16       France       54       72         29      70
#
#              Balance Ball control Composure Crossing         ...          \
# Name                                                         ...
# J. Romero     86           55        59       46             ...
# J. Hove       56           51        42       40             ...
# Javi Vázquez  65           47        43       33             ...
# K. Pierie     53           65        66       47             ...
# L. Pintor     68           56        43       27             ...
#
#              Short passing Shot power Sliding tackle Sprint speed Stamina  \
# Name
# J. Romero           52         54             25           77      58
# J. Hove             56         50             56           64      47
# Javi Vázquez        41         42             59           64      59
# K. Pierie           68         35             62           72      45
# L. Pintor           30         57             12           68      36
#
#              Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# J. Romero             26       41      51      45                     ST
# J. Hove               51       54      56      29                     CM
# Javi Vázquez          63       55      37      29                     CB
# K. Pierie             67       65      56      32                  LB CB
# L. Pintor             10       34      38      48                     ST
#
# [5 rows x 38 columns]

# %% [markdown]
# When sorting values, the default is always ascending. If we want to sort in decending order, we need to pass ascending=False.

# %%
# Sort by age from oldest to youngest (select first 5 entries)
df.sort_values(by='Age', ascending=False).head()
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# B. Richardson   47     England       46       25         44      35
# E. El Hadary    44       Egypt       70       28         29      21
# O. Pérez        44      Mexico       71       60         26      69
# J. Walker       43     England       55       22         41      53
# D. Coyne        43       Wales       55       36         36      48
#
#               Balance Ball control Composure Crossing         ...          \
# Name                                                          ...
# B. Richardson  44           22        44       11             ...
# E. El Hadary   41           25        57       20             ...
# O. Pérez       69           23        50       19             ...
# J. Walker      64           38        35       16             ...
# D. Coyne       58           31        57       13             ...
#
#               Short passing Shot power Sliding tackle Sprint speed Stamina  \
# Name
# B. Richardson        12         13             13           25      32
# E. El Hadary         16         18             15           39      34
# O. Pérez             26         24             11           57      41
# J. Walker            22         22             13           35      19
# D. Coyne             28         21             19           33      37
#
#               Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# B. Richardson          12       47      17      12                     GK
# E. El Hadary           19       73      16      12                     GK
# O. Pérez               12       66      40      13                     GK
# J. Walker              11       62      32      11                     GK
# D. Coyne               16       76      33      11                     GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Filtering

# %% [markdown]
# A very useful thing to do with a dataframe is to filter the values to only view the data you are interested in. We can do this by passing a condition inside square brackets after the dataframe, eg. the syntax will look like dataframe[condition]. Let's look at a few examples:

# %%
# Filter on players older than 30
df[df['Age'] > 30]
# Out:
#                    Age          Nationality  Overall Acceleration Aggression  \
# Name
# Cristiano Ronaldo   32             Portugal       94       89         63
# M. Neuer            31              Germany       92       58         29
# Sergio Ramos        31                Spain       90       75         84
# L. Modrić           31              Croatia       89       75         62
# G. Chiellini        32                Italy       89       68         92
# G. Buffon           39                Italy       89       49         38
# D. Godín            31              Uruguay       88       62         86
# Thiago Silva        32               Brazil       88       70         77
# Z. Ibrahimović      35               Sweden       88       63         84
# A. Robben           33          Netherlands       88       87         47
# David Silva         31                Spain       87       72         51
# S. Handanovič       32             Slovenia       87       54         25
# Iniesta             33                Spain       87       72         58
# Miranda             32               Brazil       86       67         83
# F. Ribéry           34               France       86       85         52
# Pepe                34             Portugal       86       65         94
# P. Čech             35       Czech Republic       86       40         17
# D. Subašić          32              Croatia       85       51         31
# C. Marchisio        31                Italy       85       78         78
# Filipe Luís         31               Brazil       85       75         81
# V. Kompany          31              Belgium       85       61         87
# A. Barzagli         36                Italy       85       64         70
# Bruno               33                Spain       84       42         79
# E. Džeko            31   Bosnia Herzegovina       84       67         51
# Falcao              31             Colombia       84       73         75
# L. Koscielny        31               France       84       74         88
# G. Cahill           31              England       84       62         84
# Dani Alves          34               Brazil       84       79         78
# Aduriz              36                Spain       84       69         82
# M. Mandžukić        31              Croatia       83       68         88
# ...                ...                  ...      ...          ...        ...
# H. Nakabayashi      31                Japan       56       20         26
# W. Brown            40              England       56       36         36
# D. Pipe             33                Wales       56       61         96
# Y. Uekusa           34                Japan       56       63         45
# D. Coyne            43                Wales       55       36         36
# K. Ishihara         38                Japan       55       36         48
# D. Mulcahy          39  Republic of Ireland       55       27         68
# S. Kanazawa         33                Japan       55       47         61
# S. Naruoka          33                Japan       55       43         27
# J. Walker           43              England       55       22         41
# N. Ishikawa         36                Japan       55       35         58
# K. Tanno            31                Japan       55       26         19
# T. Torske           33               Norway       55       61         53
# K. Singh            31                India       54       47         20
# B. Molloy           33  Republic of Ireland       54       32         64
# J. McCombe          34              England       54       20         60
# J. Robben           34              Germany       54       48         62
# J. Bittner          35              England       54       34         34
# R. Iuliano          33                Italy       53       30         33
# N. Hatta            31                Japan       53       31         22
# I. Homma            36                Japan       52       55         50
# R. Kawai            38                Japan       52       39         54
# K. Ishii            31                Japan       52       69         29
# Y. Nishibe          36                Japan       52       25         17
# A. Al Basisi        39         Saudi Arabia       52       46         22
# P. Jennings         37              England       52       38         40
# K. Tokushige        33                Japan       51       25         18
# H. Tanaka           34                Japan       49       41         92
# Y. Uchimura         32                Japan       48       40         31
# B. Richardson       47              England       46       25         44
#
#                   Agility Balance Ball control Composure Crossing  \
# Name
# Cristiano Ronaldo  89      63           93        95       85
# M. Neuer           52      35           48        70       15
# Sergio Ramos       79      60           84        80       66
# L. Modrić          93      94           92        84       78
# G. Chiellini       59      64           57        82       58
# G. Buffon          55      49           28        70       13
# D. Godín           63      58           76        82       55
# Thiago Silva       74      68           80        83       60
# Z. Ibrahimović     81      41           88        91       76
# A. Robben          89      91           89        86       80
# David Silva        92      89           90        92       83
# S. Handanovič      42      36           24        62       12
# Iniesta            79      84           94        89       77
# Miranda            61      57           72        84       48
# F. Ribéry          88      91           90        86       81
# Pepe               63      49           62        77       46
# P. Čech            49      34           22        70       19
# D. Subašić         42      37           19        65       11
# C. Marchisio       81      79           85        84       76
# Filipe Luís        74      60           81        88       84
# V. Kompany         60      42           68        81       61
# A. Barzagli        51      64           65        82       40
# Bruno              53      59           83        86       60
# E. Džeko           57      36           80        79       63
# Falcao             85      75           82        87       55
# L. Koscielny       68      62           67        75       52
# G. Cahill          62      51           63        75       28
# Dani Alves         85      87           86        82       86
# Aduriz             53      57           80        87       54
# M. Mandžukić       67      53           77        80       72
# ...                   ...     ...          ...       ...      ...
# H. Nakabayashi     23      46           19        33       11
# W. Brown           31      35           19        29       11
# D. Pipe            53      72           57        52       60
# Y. Uekusa          61      56           35        34       35
# D. Coyne           48      58           31        57       13
# K. Ishihara        65      75           59        47       54
# D. Mulcahy         38      52           52        59       52
# S. Kanazawa        66      73           63        52       53
# S. Naruoka         82      72           56        57       55
# J. Walker          53      64           38        35       16
# N. Ishikawa        70      68           57        57       62
# K. Tanno           29      49           18        25       14
# T. Torske          54      68           51        66       49
# K. Singh           64      62           18        27       14
# B. Molloy          42      49           50        58       41
# J. McCombe         23      22           31        54       24
# J. Robben          56      59           61        55       54
# J. Bittner         36      42           25        41       10
# R. Iuliano         31      45           20        35       17
# N. Hatta           25      45           12        24       12
# I. Homma           56      79           41        38       39
# R. Kawai           35      55           47        65       39
# K. Ishii           54      74           49        44       49
# Y. Nishibe         25      32           13        67       14
# A. Al Basisi       38      49           20        24       16
# P. Jennings        54      50           22        46       18
# K. Tokushige       38      39           12        41       12
# H. Tanaka          58      78           42        47       44
# Y. Uchimura        33      65           57        62       51
# B. Richardson      35      44           22        44       11
#
#                           ...         Short passing Shot power Sliding tackle  \
# Name                      ...
# Cristiano Ronaldo         ...                83         94             23
# M. Neuer                  ...                55         25             11
# Sergio Ramos              ...                78         79             91
# L. Modrić                 ...                92         73             73
# G. Chiellini              ...                59         78             90
# G. Buffon                 ...                37         39             11
# D. Godín                  ...                79         67             89
# Thiago Silva              ...                79         74             88
# Z. Ibrahimović            ...                84         91             27
# A. Robben                 ...                84         87             26
# David Silva               ...                91         71             29
# S. Handanovič             ...                36         22             13
# Iniesta                   ...                92         65             56
# Miranda                   ...                70         70             86
# F. Ribéry                 ...                86         76             26
# Pepe                      ...                70         63             87
# P. Čech                   ...                35         21             12
# D. Subašić                ...                24         24             13
# C. Marchisio              ...                87         82             80
# Filipe Luís               ...                78         71             86
# V. Kompany                ...                72         75             84
# A. Barzagli               ...                65         54             88
# Bruno                     ...                87         84             85
# E. Džeko                  ...                77         86             16
# Falcao                    ...                78         79             19
# L. Koscielny              ...                76         54             84
# G. Cahill                 ...                65         63             84
# Dani Alves                ...                83         86             83
# Aduriz                    ...                71         83             49
# M. Mandžukić              ...                75         78             64
# ...                       ...                   ...        ...            ...
# H. Nakabayashi            ...                21         19             35
# W. Brown                  ...                16         16             16
# D. Pipe                   ...                56         36             58
# Y. Uekusa                 ...                46         40             17
# D. Coyne                  ...                28         21             19
# K. Ishihara               ...                57         53             50
# D. Mulcahy                ...                49         56             51
# S. Kanazawa               ...                63         67             55
# S. Naruoka                ...                58         55             22
# J. Walker                 ...                22         22             13
# N. Ishikawa               ...                59         53             38
# K. Tanno                  ...                23         23             13
# T. Torske                 ...                52         44             49
# K. Singh                  ...                23         15             14
# B. Molloy                 ...                55         42             55
# J. McCombe                ...                39         21             54
# J. Robben                 ...                65         54             32
# J. Bittner                ...                23         15             13
# R. Iuliano                ...                32         28             20
# N. Hatta                  ...                23         12             13
# I. Homma                  ...                52         48             52
# R. Kawai                  ...                62         37             55
# K. Ishii                  ...                44         67             24
# Y. Nishibe                ...                29         19             12
# A. Al Basisi              ...                21         19             20
# P. Jennings               ...                35         24             12
# K. Tokushige              ...                31         20             12
# H. Tanaka                 ...                57         48             49
# Y. Uchimura               ...                60         40             42
# B. Richardson             ...                12         13             13
#
#                   Sprint speed Stamina Standing tackle Strength  Vision  \
# Name
# Cristiano Ronaldo       91      92              31       80      85
# M. Neuer                61      44              10       83      70
# Sergio Ramos            77      84              89       81      63
# L. Modrić               71      82              80       58      90
# G. Chiellini            78      68              92       91      50
# G. Buffon               43      39              11       69      50
# D. Godín                67      67              86       80      52
# Thiago Silva            74      74              89       81      74
# Z. Ibrahimović          67      71              41       88      83
# A. Robben               86      68              26       67      83
# David Silva             65      78              44       56      92
# S. Handanovič           57      41              10       71      41
# Iniesta                 71      58              57       58      94
# Miranda                 74      65              90       80      58
# F. Ribéry               79      64              25       60      86
# Pepe                    70      62              86       84      48
# P. Čech                 44      32              13       65      53
# D. Subašić              54      32              14       80      52
# C. Marchisio            78      81              78       70      84
# Filipe Luís             82      91              83       74      70
# V. Kompany              64      74              85       88      59
# A. Barzagli             76      46              90       87      62
# Bruno                   41      76              84       77      83
# E. Džeko                61      70              28       82      70
# Falcao                  66      68              42       75      68
# L. Koscielny            76      75              87       76      56
# G. Cahill               63      69              85       80      56
# Dani Alves              84      76              79       55      78
# Aduriz                  70      64              44       83      73
# M. Mandžukić            76      87              64       87      74
# ...                        ...     ...             ...      ...     ...
# H. Nakabayashi          26      27              20       43      46
# W. Brown                22      24              14       62      15
# D. Pipe                 59      67              51       85      53
# Y. Uekusa               60      44              23       54      48
# D. Coyne                33      37              16       76      33
# K. Ishihara             38      36              51       56      55
# D. Mulcahy              30      34              53       67      55
# S. Kanazawa             42      33              56       46      48
# S. Naruoka              43      71              22       62      58
# J. Walker               35      19              11       62      32
# N. Ishikawa             45      53              41       60      56
# K. Tanno                23      22              11       45      45
# T. Torske               56      65              53       51      52
# K. Singh                42      33              15       53      15
# B. Molloy               31      33              56       65      50
# J. McCombe              21      42              52       75      19
# J. Robben               61      43              44       66      53
# J. Bittner              44      29              15       60      11
# R. Iuliano              34      24              18       53      33
# N. Hatta                26      14              12       42      34
# I. Homma                61      46              57       41      38
# R. Kawai                45      30              59       39      40
# K. Ishii                68      49              24       36      40
# Y. Nishibe              24      18              12       49      40
# A. Al Basisi            49      37              13       79      16
# P. Jennings             38      37              13       43      21
# K. Tokushige            20      23              13       62      33
# H. Tanaka               55      76              41       56      42
# Y. Uchimura             39      29              42       37      47
# B. Richardson           25      32              12       47      17
#
#                   Volleys Preferred Positions
# Name
# Cristiano Ronaldo  88                  ST LW
# M. Neuer           11                     GK
# Sergio Ramos       66                     CB
# L. Modrić          74                 CDM CM
# G. Chiellini       45                     CB
# G. Buffon          17                     GK
# D. Godín           47                     CB
# Thiago Silva       63                     CB
# Z. Ibrahimović     90                     ST
# A. Robben          86                  RW RM
# David Silva        79              LM CM CAM
# S. Handanovič      12                     GK
# Iniesta            74                  LM CM
# Miranda            51                     CB
# F. Ribéry          80                  LW LM
# Pepe               23                     CB
# P. Čech            17                     GK
# D. Subašić         13                     GK
# C. Marchisio       76                 CDM CM
# Filipe Luís        56                     LB
# V. Kompany         46                     CB
# A. Barzagli        35                     CB
# Bruno              48                 CDM CM
# E. Džeko           77                     ST
# Falcao             84                     ST
# L. Koscielny       35                     CB
# G. Cahill          47                     CB
# Dani Alves         68                     RB
# Aduriz             84                     ST
# M. Mandžukić       86                  LM ST
# ...                   ...                 ...
# H. Nakabayashi      5                     GK
# W. Brown           15                     GK
# D. Pipe            13                 RB RWB
# Y. Uekusa          13                     GK
# D. Coyne           11                     GK
# K. Ishihara        47                    CAM
# D. Mulcahy         44                 CDM CB
# S. Kanazawa        35                 CM CDM
# S. Naruoka         47                  RM LM
# J. Walker          11                     GK
# N. Ishikawa        48                     RW
# K. Tanno            8                     GK
# T. Torske          46                  LM LB
# K. Singh           17                     GK
# B. Molloy          32                 CM CDM
# J. McCombe         21                     CB
# J. Robben          60                 RM CDM
# J. Bittner         14                     GK
# R. Iuliano         14                     GK
# N. Hatta           10                     GK
# I. Homma           25                    CDM
# R. Kawai           27                 CB CDM
# K. Ishii           53               RW LM RM
# Y. Nishibe          6                     GK
# A. Al Basisi       11                     GK
# P. Jennings        14                     GK
# K. Tokushige        5                     GK
# H. Tanaka          35                 CDM CM
# Y. Uchimura        38                    CAM
# B. Richardson      12                     GK
#
# [2534 rows x 38 columns]

# %% [markdown]
# We can also pass multiple conditions in the square brackets by using the | and & operators. Note that each condition should be closed inside round brackets as well.

# %%
# Filter on players older than 30 and overall rating greater than 90
df[(df['Age'] > 30) & (df['Overall'] > 90)]
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing         ...          \
# Name                                                              ...
# Cristiano Ronaldo  63           93        95       85             ...
# M. Neuer           35           48        70       15             ...
#
#                   Short passing Shot power Sliding tackle Sprint speed  \
# Name
# Cristiano Ronaldo        83         94             23           91
# M. Neuer                 55         25             11           61
#
#                   Stamina Standing tackle Strength  Vision Volleys  \
# Name
# Cristiano Ronaldo  92              31       80      85      88
# M. Neuer           44              10       83      70      11
#
#                   Preferred Positions
# Name
# Cristiano Ronaldo              ST LW
# M. Neuer                          GK
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Create and Drop Columns

# %% [markdown]
# Another useful thing is to create new columns from existing ones as well as to drop columns that are not needed.

# %% [markdown]
# ### Create Columns

# %% [markdown]
# We can create new columns from existing ones by simply defining the new name as a string inside square brackets after calling the dataframe followed by the function of the other column(s). Let's look at an example:

# %%
# Create column of rating per year of age
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at first 5 entries
df['Rating Per Year of Age'].head()
# Out:
# Name
# Cristiano Ronaldo    2.937500
# L. Messi             3.100000
# Neymar               3.680000
# L. Suárez            3.066667
# M. Neuer             2.967742
# Name: Rating Per Year of Age, dtype: float64

# %% [markdown]
# ### Drop Columns

# %% [markdown]
# Columns can be dropped by using the `drop()` function. The arguments are the column name (string) and the axis which should be equal to 1.

# %%
# Drop column just created
df = df.drop('Rating Per Year of Age', axis=1)

df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing         ...          \
# Name                                                              ...
# Cristiano Ronaldo  63           93        95       85             ...
# L. Messi           95           95        96       77             ...
# Neymar             82           95        92       75             ...
# L. Suárez          60           91        83       77             ...
# M. Neuer           35           48        70       15             ...
#
#                   Short passing Shot power Sliding tackle Sprint speed  \
# Name
# Cristiano Ronaldo        83         94             23           91
# L. Messi                 88         85             26           87
# Neymar                   81         80             33           90
# L. Suárez                83         87             38           77
# M. Neuer                 55         25             11           61
#
#                   Stamina Standing tackle Strength  Vision Volleys  \
# Name
# Cristiano Ronaldo  92              31       80      85      88
# L. Messi           73              28       59      90      85
# Neymar             78              24       53      80      83
# L. Suárez          89              45       80      84      88
# M. Neuer           44              10       83      70      11
#
#                   Preferred Positions
# Name
# Cristiano Ronaldo              ST LW
# L. Messi                          RW
# Neymar                            LW
# L. Suárez                         ST
# M. Neuer                          GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Group Data

# %% [markdown]
# We can also group the data according to some column(s). This will help if we are interested in certain groups within the dataset. We use the `groupby()` function to do this.
#
# Note that after the `groupby()` function we need to call an aggregation function for the grouped data. Examples are `mean()`, `sum()`, `min()` and `max()`. It will then return a column of the chosen aggregation for each numeric column. We can also then select the columns we want to see. Let's look at an example:

# %%
# Look at the average rating by age (first 5 rows)
df.groupby('Age').mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %% [markdown]
# It is possible to group by more than one column. We simply need to pass the list of columns.

# %%
# Look at the average rating by age and nationality (first 5 rows)
df.groupby(['Age', 'Nationality']).mean().head()
# Out:
#                  Overall
# Age Nationality
# 16  Argentina       56.0
#     England         61.5
#     France          54.0
#     Germany         57.0
#     Italy           61.0

# %% [markdown]
# ## Transforming Data

# %% [markdown]
# It is often the case that we want to format a column or columns inside our dataframe. We can transform a column using the `apply()` function, while we use the `applymap()` function to transform all the columns at once. The argument for these functions is a function that must be applied to the specific column or columns.
#
# We can create a function by using `def` or `lambda expressions`.

# %% [markdown]
# ### Def Expression

# %% [markdown]
# Let's format a column in our dataset. We start by creating the function.

# %%
# Using def
def year_to_month(x):
    "Converts no of years to no of months"
    return x * 12

# %%
# Change the age column to months and look at first 5 entries
df['Age'].apply(year_to_month).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### Lambda Expressions

# %% [markdown]
# You briefly covered lambda expressions in the Python Fundamentals. But let's have a quick recap:
#
# Lambda operator or lambda function is used for creating small, one-time and anonymous function objects in Python. Basic syntax:
#
# * `lambda` *arguments*: *expression*
#
# Lambda operator can have any number of arguments, but it can have only one expression. It cannot contain any statements and it returns a function object which can be assigned to any variable.
#
# Let's look at an example:

# %%
# Using lambda operator
year_to_month_lamb = lambda x: x * 12

# Print function answer
print('def: ', year_to_month(30))
print('lambda: ', year_to_month_lamb(30))
# Out:
# def:  360
# lambda:  360

# %% [markdown]
# So essentially it does the same as `def`, but it can only have one expression and there is no need to return anything.
#
# Let's use it to format a column in our dataset:

# %%
# Change the age column to months and look at first 5 entries
df['Age'].apply(lambda x: x*12).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### More Examples

# %% [markdown]
# For practice, let's create another function to create a column with the player position type, where types can be Forward, Midfielder, Back or GoalKeeper.

# %%
# Create function
def position_type(s):
    
    """"This function converts the individual positions (abbreviations) and classfies it
    as either a forward, midfielder, back or goal keeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# %%
# Create position type column
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# Look at first 5 entries
df['Preferred Positions Type'].head()
# Out:
# Name
# Cristiano Ronaldo       Forward
# L. Messi                Forward
# Neymar                  Forward
# L. Suárez               Forward
# M. Neuer             GoalKeeper
# Name: Preferred Positions Type, dtype: object

# %% [markdown]
# Let's create another function to transform many columns at once using the `applymap()` function.
#
# A lot of the columns look like they should be numbers, but are actually stored as strings. We can check this by using the `info()` function:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
# Age                         17981 non-null int64
# Nationality                 17981 non-null object
# Overall                     17981 non-null int64
# Acceleration                17981 non-null object
# Aggression                  17981 non-null object
# Agility                     17981 non-null object
# Balance                     17981 non-null object
# Ball control                17981 non-null object
# Composure                   17981 non-null object
# Crossing                    17981 non-null object
# Curve                       17981 non-null object
# Dribbling                   17981 non-null object
# Finishing                   17981 non-null object
# Free kick accuracy          17981 non-null object
# GK diving                   17981 non-null object
# GK handling                 17981 non-null object
# GK kicking                  17981 non-null object
# GK positioning              17981 non-null object
# GK reflexes                 17981 non-null object
# Heading accuracy            17981 non-null object
# Interceptions               17981 non-null object
# Jumping                     17981 non-null object
# Long passing                17981 non-null object
# Long shots                  17981 non-null object
# Marking                     17981 non-null object
# Penalties                   17981 non-null object
# Positioning                 17981 non-null object
# Reactions                   17981 non-null object
# Short passing               17981 non-null object
# Shot power                  17981 non-null object
# Sliding tackle              17981 non-null object
# Sprint speed                17981 non-null object
# Stamina                     17981 non-null object
# Standing tackle             17981 non-null object
# Strength                    17981 non-null object
# Vision                      17981 non-null object
# Volleys                     17981 non-null object
# Preferred Positions         17981 non-null object
# Preferred Positions Type    17981 non-null object
# dtypes: int64(2), object(37)
# memory usage: 5.5+ MB

# %% [markdown]
# As you can see, most of the number columns (attributes) are stored as strings.
#
# We will create a function that transforms all the supposed number columns, to floats. For the strings, we will only select the first two characters to transform so that it returns a two digit number before the comma.

# %%
# Select all attribute columns
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
# Create function
def to_float(x):    
    "Transforms attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

# %%
# Use applymap() function to transform all selected columns
df[cols] = df[cols].applymap(to_float)

# %% [markdown]
# Now let's look at the data types of the columns:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
# Age                         17981 non-null int64
# Nationality                 17981 non-null object
# Overall                     17981 non-null float64
# Acceleration                17981 non-null float64
# Aggression                  17981 non-null float64
# Agility                     17981 non-null float64
# Balance                     17981 non-null float64
# Ball control                17981 non-null float64
# Composure                   17981 non-null float64
# Crossing                    17981 non-null float64
# Curve                       17981 non-null float64
# Dribbling                   17981 non-null float64
# Finishing                   17981 non-null float64
# Free kick accuracy          17981 non-null float64
# GK diving                   17981 non-null float64
# GK handling                 17981 non-null float64
# GK kicking                  17981 non-null float64
# GK positioning              17981 non-null float64
# GK reflexes                 17981 non-null float64
# Heading accuracy            17981 non-null float64
# Interceptions               17981 non-null float64
# Jumping                     17981 non-null float64
# Long passing                17981 non-null float64
# Long shots                  17981 non-null float64
# Marking                     17981 non-null float64
# Penalties                   17981 non-null float64
# Positioning                 17981 non-null float64
# Reactions                   17981 non-null float64
# Short passing               17981 non-null float64
# Shot power                  17981 non-null float64
# Sliding tackle              17981 non-null float64
# Sprint speed                17981 non-null float64
# Stamina                     17981 non-null float64
# Standing tackle             17981 non-null float64
# Strength                    17981 non-null float64
# Vision                      17981 non-null float64
# Volleys                     17981 non-null float64
# Preferred Positions         17981 non-null object
# Preferred Positions Type    17981 non-null object
# dtypes: float64(35), int64(1), object(3)
# memory usage: 5.5+ MB

# %% [markdown]
# **NB Note:**
#
# **Use the two functions in this section (More Examples) for your project deliverable to distinguish between defenders (backs) and attackers (forwards), and also to transform your attribute columns to floats (i.e. perform these two transformations on the data before attempting to create the functions required for the project deliverable).**

# %% [markdown]
# ## Exercises
# #### Using the above dataframe, who is the oldest player with an Overall of at least 70?

# %%
df.sort_values(['Overall','Age'], ascending = False)
# Out:
#                    Age          Nationality  Overall  Acceleration  \
# Name
# Cristiano Ronaldo   32             Portugal     94.0          89.0
# L. Messi            30            Argentina     93.0          92.0
# M. Neuer            31              Germany     92.0          58.0
# L. Suárez           30              Uruguay     92.0          88.0
# Neymar              25               Brazil     92.0          94.0
# R. Lewandowski      28               Poland     91.0          79.0
# Sergio Ramos        31                Spain     90.0          75.0
# G. Higuaín          29            Argentina     90.0          78.0
# T. Kroos            27              Germany     90.0          60.0
# De Gea              26                Spain     90.0          57.0
# E. Hazard           26              Belgium     90.0          93.0
# G. Buffon           39                Italy     89.0          49.0
# G. Chiellini        32                Italy     89.0          68.0
# L. Modrić           31              Croatia     89.0          75.0
# S. Agüero           29            Argentina     89.0          90.0
# A. Sánchez          28                Chile     89.0          88.0
# G. Bale             27                Wales     89.0          93.0
# K. De Bruyne        26              Belgium     89.0          76.0
# T. Courtois         25              Belgium     89.0          46.0
# Z. Ibrahimović      35               Sweden     88.0          63.0
# A. Sánchez             80.0            ...                   84.0
# G. Bale                87.0            ...                   91.0
# K. De Bruyne           90.0            ...                   85.0
# T. Courtois            14.0            ...                   36.0
# Z. Ibrahimović         76.0            ...                   91.0
# A. Robben              80.0            ...                   87.0
# Thiago Silva           60.0            ...                   74.0
# D. Godín               55.0            ...                   67.0
# L. Bonucci             44.0            ...                   74.0
# H. Lloris              13.0            ...                   23.0
# P. Aubameyang          77.0            ...                   81.0
# J. Boateng             69.0            ...                   79.0
# M. Hummels             64.0            ...                   71.0
# M. Özil                82.0            ...                   70.0
# A. Griezmann           82.0            ...                   81.0
# ...                     ...            ...                    ...
# B. Sass-Davies         28.0            ...                   35.0
# L. Walsh               30.0            ...                   40.0
# R. Roache              32.0            ...                   46.0
# D. Amos                41.0            ...                   42.0
# A. Osmanoski           35.0            ...                   49.0
# Z. Mohammed            24.0            ...                   35.0
# G. Manley              32.0            ...                   43.0
# K. Egan                47.0            ...                   22.0
# A. Kilgour             29.0            ...                   43.0
# A. Conway              51.0            ...                   44.0
# N. McLaughlin          34.0            ...                   48.0
# L. Kiely               35.0            ...                   44.0
# J. Payne               37.0            ...                   22.0
# P. Phillips            31.0            ...                   46.0
# A. Byrne               34.0            ...                   54.0
# K. Fujikawa            31.0            ...                   42.0
# F. Prohart             32.0            ...                   45.0
# R. White               28.0            ...                   52.0
# D. Peppard             39.0            ...                   39.0
# C. Rogers              37.0            ...                   38.0
# J. Latibeaudiere       21.0            ...                   32.0
# T. Brownsword          25.0            ...                   32.0
# B. Richardson          11.0            ...                   13.0
# T. Käßemodel           42.0            ...                   52.0
# T. Sawyer              36.0            ...                   41.0
# J. Keeble              28.0            ...                   30.0
# J. Lundstram           34.0            ...                   43.0
# L. Sackey              19.0            ...                   21.0
# A. Kelsey              14.0            ...                   19.0
# J. Young               28.0            ...                   42.0
#
#                    Sliding tackle  Sprint speed  Stamina  Standing tackle  \
# Name
# Cristiano Ronaldo            23.0          91.0     92.0             31.0
# L. Messi                     26.0          87.0     73.0             28.0
# M. Neuer                     11.0          61.0     44.0             10.0
# L. Suárez                    38.0          77.0     89.0             45.0
# Neymar                       33.0          90.0     78.0             24.0
# R. Lewandowski               19.0          83.0     79.0             42.0
# Sergio Ramos                 91.0          77.0     84.0             89.0
# G. Higuaín                   18.0          80.0     72.0             22.0
# T. Kroos                     69.0          52.0     77.0             82.0
# De Gea                       13.0          58.0     40.0             21.0
# E. Hazard                    22.0          87.0     79.0             27.0
# G. Buffon                    11.0          43.0     39.0             11.0
# G. Chiellini                 90.0          78.0     68.0             92.0
# L. Modrić                    73.0          71.0     82.0             80.0
# S. Agüero                    12.0          84.0     74.0             20.0
# A. Sánchez                   35.0          84.0     85.0             39.0
# G. Bale                      52.0          95.0     76.0             55.0
# K. De Bruyne                 40.0          75.0     87.0             51.0
# T. Courtois                  16.0          52.0     38.0             18.0
# Z. Ibrahimović               27.0          67.0     71.0             41.0
# A. Robben                    26.0          86.0     68.0             26.0
# Thiago Silva                 88.0          74.0     74.0             89.0
# A. Robben              67.0    83.0     86.0               RW RM
# Thiago Silva           81.0    74.0     63.0                  CB
# D. Godín               80.0    52.0     47.0                  CB
# L. Bonucci             85.0    74.0     58.0                  CB
# H. Lloris              43.0    30.0     11.0                  GK
# P. Aubameyang          77.0    77.0     86.0                  ST
# J. Boateng             91.0    76.0     53.0                  CB
# M. Hummels             85.0    79.0     60.0                  CB
# M. Özil                57.0    92.0     77.0              RW CAM
# A. Griezmann           61.0    76.0     87.0            LW RW ST
# ...                     ...     ...      ...                  ...
# B. Sass-Davies         61.0    33.0     21.0                  CB
# L. Walsh               34.0    47.0     32.0              CAM ST
# R. Roache              44.0    41.0     35.0                  ST
# D. Amos                56.0    46.0     35.0               LM LB
# A. Osmanoski           58.0    42.0     32.0                  CM
# Z. Mohammed            63.0    32.0     20.0                  CB
# G. Manley              46.0    47.0     30.0                  CM
# K. Egan                63.0    32.0     23.0                  RB
# A. Kilgour             68.0    31.0     19.0                  CB
# A. Conway              48.0    40.0     33.0        CB LW LWB LB
# N. McLaughlin          58.0    47.0     41.0              CAM ST
# L. Kiely               49.0    53.0     42.0                 CAM
# J. Payne               60.0    32.0     26.0               CB LB
# P. Phillips            50.0    51.0     31.0                  CM
# A. Byrne               31.0    40.0     37.0                  CM
# K. Fujikawa            42.0    51.0     31.0                  CM
# F. Prohart             41.0    47.0     36.0                  ST
# R. White               61.0    48.0     35.0            ST RM LM
# D. Peppard             36.0    38.0     28.0                  RB
# C. Rogers              57.0    32.0     21.0               CB RB
# J. Latibeaudiere       45.0    27.0     20.0                  CB
# T. Brownsword          50.0    32.0     21.0                  CB
# B. Richardson          47.0    17.0     12.0                  GK
# T. Käßemodel           37.0    43.0     34.0                  CM
# T. Sawyer              40.0    40.0     33.0                  CM
# J. Keeble              42.0    28.0     24.0                  CB
# J. Lundstram           46.0    51.0     25.0                  CM
# L. Sackey              67.0    22.0     19.0               ST CB
# A. Kelsey              50.0    26.0      6.0                  GK
# J. Young               32.0    37.0     33.0                  ST
#
#                    Preferred Positions Type
# Name
# Cristiano Ronaldo                   Forward
# L. Messi                            Forward
# M. Neuer                         GoalKeeper
# L. Suárez                           Forward
# Neymar                              Forward
# R. Lewandowski                      Forward
# Sergio Ramos                           Back
# G. Higuaín                          Forward
# T. Kroos                         Midfielder
# De Gea                           GoalKeeper
# E. Hazard                           Forward
# G. Buffon                        GoalKeeper
# G. Chiellini                           Back
# L. Modrić                        Midfielder
# S. Agüero                           Forward
# A. Sánchez                       Midfielder
# G. Bale                             Forward
# K. De Bruyne                     Midfielder
# T. Courtois                      GoalKeeper
# Z. Ibrahimović                      Forward
# A. Robben                        Midfielder
# Thiago Silva                           Back
# D. Godín                               Back
# L. Bonucci                             Back
# H. Lloris                        GoalKeeper
# P. Aubameyang                       Forward
# J. Boateng                             Back
# M. Hummels                             Back
# M. Özil                          Midfielder
# A. Griezmann                        Forward
# ...                                     ...
# B. Sass-Davies                         Back
# L. Walsh                            Forward
# R. Roache                           Forward
# D. Amos                                Back
# A. Osmanoski                     Midfielder
# Z. Mohammed                            Back
# G. Manley                        Midfielder
# K. Egan                                Back
# A. Kilgour                             Back
# A. Conway                              Back
# N. McLaughlin                       Forward
# L. Kiely                         Midfielder
# J. Payne                               Back
# P. Phillips                      Midfielder
# A. Byrne                         Midfielder
# K. Fujikawa                      Midfielder
# F. Prohart                          Forward
# R. White                         Midfielder
# D. Peppard                             Back
# C. Rogers                              Back
# J. Latibeaudiere                       Back
# T. Brownsword                          Back
# B. Richardson                    GoalKeeper
# T. Käßemodel                     Midfielder
# T. Sawyer                        Midfielder
# J. Keeble                              Back
# J. Lundstram                     Midfielder
# L. Sackey                              Back
# A. Kelsey                        GoalKeeper
# J. Young                            Forward
#
# [17981 rows x 39 columns]

# %%
df[df['Age']]
# Out:
#                Age Nationality  Overall  Acceleration  Aggression  Agility  \
# Name
# B. Richardson   47     England     46.0          25.0        44.0     35.0
# E. El Hadary    44       Egypt     70.0          28.0        29.0     21.0
# O. Pérez        44      Mexico     71.0          60.0        26.0     69.0
# J. Walker       43     England     55.0          22.0        41.0     53.0
# D. Coyne        43       Wales     55.0          36.0        36.0     48.0
#
#                Balance  Ball control  Composure  Crossing  \
# Name
# B. Richardson     44.0          22.0       44.0      11.0
# E. El Hadary      41.0          25.0       57.0      20.0
# O. Pérez          69.0          23.0       50.0      19.0
# J. Walker         64.0          38.0       35.0      16.0
# D. Coyne          58.0          31.0       57.0      13.0
#
#                          ...             Shot power  Sliding tackle  \
# Name                     ...
# B. Richardson            ...                   13.0            13.0
# E. El Hadary             ...                   18.0            15.0
# O. Pérez                 ...                   24.0            11.0
# J. Walker                ...                   22.0            13.0
# D. Coyne                 ...                   21.0            19.0
#
#                Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# Name
# B. Richardson          25.0     32.0             12.0      47.0    17.0
# E. El Hadary           39.0     34.0             19.0      73.0    16.0
# O. Pérez               57.0     41.0             12.0      66.0    40.0
# J. Walker              35.0     19.0             11.0      62.0    32.0
# D. Coyne               33.0     37.0             16.0      76.0    33.0
#
#                Volleys  Preferred Positions  Preferred Positions Type
# Name
# B. Richardson     12.0                  GK                 GoalKeeper
# E. El Hadary      12.0                  GK                 GoalKeeper
# O. Pérez          13.0                  GK                 GoalKeeper
# J. Walker         11.0                  GK                 GoalKeeper
# D. Coyne          11.0                  GK                 GoalKeeper
#
# [5 rows x 39 columns]

# %% [markdown]
# #### What is the age of the youngest Norweigian player?

# %%
df[df['Nationality'] ==  'Norway' ]
# Out:
#                  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# Name
# R. Jarstein       32      Norway     82.0          40.0        34.0     35.0
# M. Elyounoussi    22      Norway     78.0          88.0        49.0     86.0
# P. Skjelbred      30      Norway     78.0          68.0        79.0     78.0
# J. King           25      Norway     77.0          87.0        50.0     78.0
# H. Nordtveit      27      Norway     77.0          63.0        78.0     61.0
# O. Selnæs         22      Norway     75.0          67.0        71.0     70.0
# O. Kamara         27      Norway     75.0          74.0        72.0     72.0
# A. Johansen       18      Norway     51.0          54.0        43.0     51.0
# T. Totland        18      Norway     50.0          60.0        53.0     74.0
# E. Solnørdal      17      Norway     50.0          57.0        54.0     81.0
# A. Bruseth        18      Norway     50.0          69.0        26.0     71.0
# J. Granlund       17      Norway     50.0          15.0        16.0     34.0
#
#                  Balance  Ball control  Composure  Crossing  \
# Name
# R. Jarstein         45.0          23.0       55.0      18.0
# M. Elyounoussi      83.0          78.0       71.0      75.0
# P. Skjelbred        81.0          80.0       75.0      69.0
# J. King             71.0          74.0       72.0      63.0
# H. Nordtveit        59.0          71.0       71.0      66.0
# O. Selnæs           66.0          76.0       75.0      62.0
# O. Kamara           70.0          77.0       74.0      50.0
# O. Elabdellaoui     79.0          74.0       66.0      73.0
# J. Svensson         85.0          70.0       71.0      70.0
# S. Johansen         75.0          76.0       75.0      69.0
# M. Ødegaard         76.0          83.0       77.0      74.0
# V. Forren           65.0          65.0       73.0      45.0
# O. Nyland           53.0          23.0       41.0      12.0
# T. Elyounoussi      90.0          75.0       69.0      68.0
# T. Reginiussen      54.0          55.0       72.0      55.0
# M. Linnes           80.0          73.0       55.0      68.0
# F. Midtsjø          86.0          75.0       73.0      60.0
# H. Aleesami         58.0          67.0       72.0      69.0
# L. Vilsvik          71.0          69.0       70.0      74.0
# P. Helland          69.0          74.0       70.0      72.0
# R. Jenssen          81.0          70.0       75.0      72.0
# M. Møller Dæhli     83.0          80.0       66.0      66.0
# A. Søderlund        51.0          66.0       73.0      53.0
# A. Tettey           74.0          63.0       66.0      60.0
# A. Hansen           43.0          24.0       64.0      13.0
# I. Fossum           75.0          72.0       63.0      57.0
# H. Nielsen          62.0          72.0       71.0      64.0
# M. Henriksen        60.0          73.0       75.0      65.0
# G. Valsvik          33.0          44.0       55.0      47.0
# S. Grytebust        43.0          23.0       39.0      11.0
# ...                  ...           ...        ...       ...
# A. Waagan           70.0          49.0       42.0      43.0
# P. Aas              68.0          59.0       48.0      49.0
# J. Barstad          51.0          29.0       44.0      28.0
# S. Sinyan           64.0          48.0       42.0      44.0
# K. Krygård          62.0          52.0       52.0      34.0
# H. Fossdal          66.0          17.0       24.0      14.0
# M. Bildøy           48.0          54.0       42.0      58.0
# S. Shamohammad      69.0          52.0       58.0      53.0
# T. Børkeeiet        65.0          52.0       43.0      40.0
# J. Isaksen          63.0          52.0       41.0      49.0
# M. Kaasa            80.0          55.0       50.0      49.0
# S. Sødergren        50.0          18.0       33.0      21.0
# H. Kristiansen      66.0          52.0       55.0      42.0
# A. Dønnum           67.0          49.0       45.0      37.0
# E. Bohinen          73.0          58.0       56.0      40.0
# E. Sandberg         64.0          35.0       41.0      27.0
# T. Omenås           44.0          35.0       28.0       9.0
# V. Støvland         53.0          46.0       51.0      35.0
# J. Kitolano         80.0          50.0       48.0      43.0
# K. Velde            74.0          52.0       51.0      29.0
# J. Hove             56.0          51.0       42.0      40.0
# J. Husebø           62.0          29.0       40.0      24.0
# T. Sørås            52.0          47.0       46.0      42.0
# K. Gunnarshaug      66.0          50.0       41.0      40.0
# O. Brynhildsen      77.0          44.0       44.0      46.0
# A. Johansen         64.0          39.0       45.0      31.0
# T. Totland          74.0          42.0       52.0      43.0
# E. Solnørdal        84.0          50.0       40.0      37.0
# A. Bruseth          77.0          48.0       48.0      32.0
# J. Granlund         42.0          10.0       31.0      11.0
#
#                            ...             Shot power  Sliding tackle  \
# Name                       ...
# R. Jarstein                ...                   21.0            13.0
# M. Elyounoussi             ...                   76.0            44.0
# P. Skjelbred               ...                   56.0            74.0
# J. King                    ...                   78.0            19.0
# H. Nordtveit               ...                   72.0            77.0
# O. Selnæs                  ...                   66.0            66.0
# O. Kamara                  ...                   73.0            19.0
# O. Elabdellaoui            ...                   72.0            72.0
# J. Svensson                ...                   74.0            74.0
# S. Johansen                ...                   73.0            59.0
# M. Ødegaard                ...                   55.0            32.0
# V. Forren                  ...                   78.0            68.0
# O. Nyland                  ...                   23.0            12.0
# T. Elyounoussi             ...                   72.0            28.0
# T. Reginiussen             ...                   61.0            72.0
# M. Linnes                  ...                   60.0            71.0
# F. Midtsjø                 ...                   68.0            58.0
# H. Aleesami                ...                   61.0            67.0
# L. Vilsvik                 ...                   77.0            68.0
# P. Helland                 ...                   86.0            49.0
# R. Jenssen                 ...                   75.0            51.0
# M. Møller Dæhli            ...                   50.0            24.0
# A. Søderlund               ...                   74.0            23.0
# A. Tettey                  ...                   85.0            69.0
# A. Hansen                  ...                   17.0            14.0
# I. Fossum                  ...                   65.0            58.0
# H. Nielsen                 ...                   76.0            33.0
# M. Henriksen               ...                   76.0            62.0
# G. Valsvik                 ...                   69.0            68.0
# S. Grytebust               ...                   17.0            13.0
# ...                        ...                    ...             ...
# A. Waagan                  ...                   53.0            15.0
# P. Aas                     ...                   53.0            31.0
# J. Barstad                 ...                   39.0            55.0
# S. Sinyan                  ...                   53.0            47.0
# K. Krygård                 ...                   51.0            13.0
# H. Fossdal                 ...                   21.0            20.0
# M. Bildøy                  ...                   64.0            38.0
# S. Shamohammad             ...                   55.0            52.0
# T. Børkeeiet               ...                   53.0            50.0
# J. Isaksen                 ...                   55.0            49.0
# M. Kaasa                   ...                   50.0            42.0
# S. Sødergren               ...                   54.0            20.0
# H. Kristiansen             ...                   56.0            48.0
# A. Dønnum                  ...                   59.0            46.0
# E. Bohinen                 ...                   50.0            42.0
# E. Sandberg                ...                   39.0            58.0
# T. Omenås                  ...                   33.0            14.0
# V. Støvland                ...                   53.0            44.0
# J. Kitolano                ...                   34.0            43.0
# K. Velde                   ...                   48.0            12.0
# J. Hove                    ...                   50.0            56.0
# J. Husebø                  ...                   38.0            51.0
# T. Sørås                   ...                   56.0            50.0
# K. Gunnarshaug             ...                   59.0            47.0
# O. Brynhildsen             ...                   52.0            52.0
# A. Johansen                ...                   39.0            53.0
# T. Totland                 ...                   22.0            51.0
# E. Solnørdal               ...                   56.0            46.0
# A. Bruseth                 ...                   44.0            12.0
# J. Granlund                ...                   22.0            10.0
#
#                  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# J. Husebø                53.0     63.0             61.0      59.0    34.0
# T. Sørås                 60.0     56.0             39.0      60.0    51.0
# K. Gunnarshaug           61.0     53.0             44.0      55.0    48.0
# O. Brynhildsen           67.0     53.0             47.0      50.0    45.0
# A. Johansen              55.0     61.0             53.0      57.0    30.0
# T. Totland               52.0     56.0             51.0      55.0    35.0
# E. Solnørdal             58.0     56.0             39.0      45.0    45.0
# A. Bruseth               60.0     53.0             12.0      49.0    45.0
# J. Granlund              30.0     24.0             12.0      44.0    26.0
#
#                  Volleys  Preferred Positions  Preferred Positions Type
# Name
# R. Jarstein         16.0                  GK                 GoalKeeper
# M. Elyounoussi      74.0        CM CAM RM LM                 Midfielder
# P. Skjelbred        40.0              CM CDM                 Midfielder
# J. King             67.0           CAM CF ST                    Forward
# H. Nordtveit        38.0           RB CDM CB                       Back
# O. Selnæs           60.0              CM CDM                 Midfielder
# O. Kamara           77.0                  ST                    Forward
# O. Elabdellaoui     55.0                  RB                       Back
# J. Svensson         61.0                  RB                       Back
# S. Johansen         64.0              CDM CM                 Midfielder
# M. Ødegaard         65.0              CAM RW                    Forward
# V. Forren           44.0                  CB                       Back
# O. Nyland           14.0                  GK                 GoalKeeper
# T. Elyounoussi      76.0               RM LM                 Midfielder
# T. Reginiussen      33.0                  CB                       Back
# M. Linnes           47.0               LB RB                       Back
# F. Midtsjø          59.0                  CM                 Midfielder
# H. Aleesami         40.0               LM LB                       Back
# L. Vilsvik          59.0               LB RB                       Back
# P. Helland          50.0                  RW                    Forward
# R. Jenssen          72.0              CDM CM                 Midfielder
# M. Møller Dæhli     54.0                 CAM                 Midfielder
# A. Søderlund        66.0                  ST                    Forward
# A. Tettey           22.0              CM CDM                 Midfielder
# A. Hansen           12.0                  GK                 GoalKeeper
# I. Fossum           47.0              CAM CM                 Midfielder
# H. Nielsen          73.0               CF ST                    Forward
# M. Henriksen        66.0              CM CAM                 Midfielder
# G. Valsvik          18.0                  CB                       Back
# S. Grytebust        13.0                  GK                 GoalKeeper
# ...                  ...                  ...                       ...
# A. Waagan           46.0                  ST                    Forward
# P. Aas              47.0                  RM                 Midfielder
# J. Barstad          23.0                  CB                       Back
# S. Sinyan           41.0               CB CM                 Midfielder
# K. Krygård          48.0                  ST                    Forward
# H. Fossdal          18.0                  GK                 GoalKeeper
# M. Bildøy           55.0                  RW                    Forward
# S. Shamohammad      47.0                  CM                 Midfielder
# T. Børkeeiet        36.0                  CM                 Midfielder
# J. Isaksen          39.0                  CM                 Midfielder
# M. Kaasa            45.0                  CM                 Midfielder
# S. Sødergren        11.0                  GK                 GoalKeeper
# H. Kristiansen      37.0                  CM                 Midfielder
# A. Dønnum           35.0                  CM                 Midfielder
# E. Bohinen          39.0                  CM                 Midfielder
# E. Sandberg         27.0                  CB                       Back
# T. Omenås           13.0                  GK                 GoalKeeper
# V. Støvland         42.0                  CM                 Midfielder
# J. Kitolano         22.0                  LB                       Back
# K. Velde            36.0                  ST                    Forward
# J. Hove             29.0                  CM                 Midfielder
# J. Husebø           22.0                  CB                       Back
# T. Sørås            41.0                  CM                 Midfielder
# K. Gunnarshaug      33.0                  CM                 Midfielder
# O. Brynhildsen      37.0                  RM                 Midfielder
# A. Johansen         30.0              CDM CB                       Back
# T. Totland          25.0                  LB                       Back
# E. Solnørdal        42.0                  CM                 Midfielder
# A. Bruseth          45.0                  ST                    Forward
# J. Granlund          9.0                  GK                 GoalKeeper
#
# [333 rows x 39 columns]

# %% [markdown]
# #### What is the average Overall for Brazillian players that are at least 26 years old?

# %%
# Out:
# 71.55246252676659

# %% [markdown]
# ## When to use Dataframes

# %%
df.groupby('Nationality',sort=1).mean().head()
df['Rating Per Year of Age']= df['Overall'].mean()
df.sort_values(by = 'Rating Per Year of Age',ascending=False).head()
# Out:
#                    Age Nationality  Overall  Acceleration  Aggression  \
# Name
# Cristiano Ronaldo   32    Portugal     94.0          89.0        63.0
# Pablo Fernández     20       Spain     63.0          68.0        32.0
# M. Perrotta         23       Italy     63.0          48.0        68.0
# D. Sappa            22   Argentina     63.0          28.0        22.0
# A. Torralvo         23    Colombia     63.0          77.0        46.0
#
#                    Agility  Balance  Ball control  Composure  Crossing  \
# Name
# Cristiano Ronaldo     89.0     63.0          93.0       95.0      85.0
# Pablo Fernández       66.0     66.0          48.0       53.0      49.0
# M. Perrotta           48.0     61.0          53.0       53.0      40.0
# D. Sappa              25.0     26.0          16.0       40.0      12.0
# A. Torralvo           84.0     84.0          56.0       45.0      69.0
#
#                             ...            Sliding tackle  Sprint speed  \
# Name                        ...
# Cristiano Ronaldo           ...                      23.0          91.0
# Pablo Fernández             ...                      32.0          67.0
# M. Perrotta                 ...                      65.0          60.0
# D. Sappa                    ...                      11.0          30.0
# A. Torralvo                 ...                      62.0          73.0
#
#                    Stamina  Standing tackle  Strength  Vision  Volleys  \
# Name
# Cristiano Ronaldo     92.0             31.0      80.0    85.0     88.0
# Pablo Fernández       59.0             32.0      64.0    41.0     59.0
# M. Perrotta           73.0             68.0      65.0    26.0     24.0
# D. Sappa              28.0             12.0      73.0    39.0      8.0
# A. Torralvo           79.0             55.0      36.0    57.0     29.0
#
#                    Preferred Positions  Preferred Positions Type  \
# Name
# Cristiano Ronaldo               ST LW                    Forward
# Pablo Fernández              CF RM ST                    Forward
# M. Perrotta                     LB CB                       Back
# D. Sappa                           GK                 GoalKeeper
# A. Torralvo                        LM                 Midfielder
#
#                    Rating Per Year of Age
# Name
# Cristiano Ronaldo               66.247984
# Pablo Fernández                 66.247984
# M. Perrotta                     66.247984
# D. Sappa                        66.247984
# A. Torralvo                     66.247984
#
# [5 rows x 40 columns]

# %% [markdown]
# DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables. It is therefore a two-dimensional labeled data structure. We should use a pandas dataframe if all of the following statements hold:
#
# * We have 2-dimensional data (rows and columns)
# * The data type is the same within a column
# * We are interested in the index (rows) and column names

# %% [markdown]
# That is the end of this tutorial. You should have a better understanding of how to manipulate pandas dataframes. You have now covered all of the tutorials in the Python Data Structures section of the course. Well done!!!
